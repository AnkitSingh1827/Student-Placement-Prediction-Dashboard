# %%
# %pip install numpy
# %pip install pandas
# Out:
# Requirement already satisfied: numpy in c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np  
import pandas as pd

# %%
df = pd.read_csv('student_placement_prediction_dataset_2026.csv')

# %%
df.head()
# Out:
#    Age  Gender  10th_Percentage  12th_Percentage   IQ  CGPA  College_Tier  \
# 0   20  Female             58.7             72.5  128  8.61             1
# 1   23    Male             92.8             71.2  101  8.86             1
# 2   23  Female             66.4             91.0  109  6.58             3
# 3   23  Female             71.1             56.4   94  7.41             3
# 4   20  Female             71.7             88.5  123  7.52             3
#
#    Communication_Skills  Technical_Skills  Aptitude_Score  Coding_Score  \
# 0                    74                77              61            36
# 1                    42                46              82            48
# 2                    53                75              40            80
# 3                    98                97              82            63
# 4                    63                36              97            75
#
#    Internships  Projects  Backlogs  Placement
# 0            0         6         0          0
# 1            0         1         0          0
# 2            2         7         0          0
# 3            0         6         0          0
# 4            3         7         0          0

# %%
#Last 5 rows of the dataset
df.tail()
# Out:
#        student_id  age  gender  cgpa      branch college_tier  \
# 99995       99996   21    Male  7.97  Mechanical       Tier 2
# 99996       99997   18  Female  7.79         CSE       Tier 1
# 99997       99998   20  Female  6.71          IT       Tier 2
# 99998       99999   19  Female  7.21         CSE       Tier 2
# 99999      100000   22  Female  8.58         ECE       Tier 3
#
#        internships_count  projects_count  certifications_count  \
# 99995                  0               3                     5
# 99996                  1               1                     2
# 99997                  2               4                     4
# 99998                  2               3                     0
# 99999                  1               3                     2
#
#        coding_skill_score  ...  mock_interview_score  attendance_percentage  \
# 99995           71.483407  ...             57.738311              75.471631
# 99996           78.960574  ...             80.076688              77.286948
# 99997           66.691775  ...             70.797752              93.115933
# 99998           67.214893  ...             68.182555              71.306355
# 99999           92.146277  ...             77.864288              89.919640
#
#        backlogs  extracurricular_score  leadership_score  \
# 99995         0              54.399022         66.446410
# 99996         1              33.692154         69.025632
# 99997         0              64.989215         32.733645
# 99998         1              72.478779         32.205517
# 99999         0              48.363818         21.166444
#
#        volunteer_experience  sleep_hours  study_hours_per_day  \
# 99995                   Yes          8.0                  4.3
# 99996                   Yes          4.4                  3.1
# 99997                   Yes          7.6                  2.9
# 99998                    No          4.9                  2.8
# 99999                   Yes          6.5                  2.9
#
#        placement_status  salary_package_lpa
# 99995            Placed               14.54
# 99996        Not Placed                0.00
# 99997            Placed               13.45
# 99998        Not Placed                0.00
# 99999            Placed               14.43
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (100000, 26)

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'cgpa', 'branch', 'college_tier',
#        'internships_count', 'projects_count', 'certifications_count',
#        'coding_skill_score', 'aptitude_score', 'communication_skill_score',
#        'logical_reasoning_score', 'hackathons_participated', 'github_repos',
#        'linkedin_connections', 'mock_interview_score', 'attendance_percentage',
#        'backlogs', 'extracurricular_score', 'leadership_score',
#        'volunteer_experience', 'sleep_hours', 'study_hours_per_day',
#        'placement_status', 'salary_package_lpa'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   student_id                 100000 non-null  int64
#  1   age                        100000 non-null  int64
#  2   gender                     100000 non-null  str
#  3   cgpa                       100000 non-null  float64
#  4   branch                     100000 non-null  str
#  5   college_tier               100000 non-null  str
#  6   internships_count          100000 non-null  int64
#  7   projects_count             100000 non-null  int64
#  8   certifications_count       100000 non-null  int64
#  9   coding_skill_score         100000 non-null  float64
#  10  aptitude_score             100000 non-null  float64
#  11  communication_skill_score  100000 non-null  float64
#  12  logical_reasoning_score    100000 non-null  float64
#  13  hackathons_participated    100000 non-null  int64
#  14  github_repos               100000 non-null  int64
#  15  linkedin_connections       100000 non-null  int64
#  16  mock_interview_score       100000 non-null  float64
#  17  attendance_percentage      100000 non-null  float64
#  18  backlogs                   100000 non-null  int64
#  19  extracurricular_score      100000 non-null  float64
#  20  leadership_score           100000 non-null  float64
#  21  volunteer_experience       100000 non-null  str
#  22  sleep_hours                100000 non-null  float64
#  23  study_hours_per_day        100000 non-null  float64
#  24  placement_status           100000 non-null  str
#  25  salary_package_lpa         100000 non-null  float64
# dtypes: float64(12), int64(9), str(5)
# memory usage: 22.2 MB

# %%
df.dtypes
# Out:
# student_id                     int64
# age                            int64
# gender                           str
# cgpa                         float64
# branch                           str
# college_tier                     str
# internships_count              int64
# projects_count                 int64
# certifications_count           int64
# coding_skill_score           float64
# aptitude_score               float64
# communication_skill_score    float64
# logical_reasoning_score      float64
# hackathons_participated        int64
# github_repos                   int64
# linkedin_connections           int64
# mock_interview_score         float64
# attendance_percentage        float64
# backlogs                       int64
# extracurricular_score        float64
# leadership_score             float64
# volunteer_experience             str
# sleep_hours                  float64
# study_hours_per_day          float64
# placement_status                 str
# salary_package_lpa           float64
# dtype: object

# %%
df.describe()
# Out:
#           student_id            age           cgpa  internships_count  \
# count  100000.000000  100000.000000  100000.000000       100000.00000
# mean    50000.500000      21.005740       7.496890            1.50223
# std     28867.657797       1.999562       0.992834            1.22528
# min         1.000000      18.000000       4.500000            0.00000
# 25%     25000.750000      19.000000       6.820000            1.00000
# 50%     50000.500000      21.000000       7.500000            1.00000
# 75%     75000.250000      23.000000       8.180000            2.00000
# max    100000.000000      24.000000      10.000000            8.00000
#
#        projects_count  certifications_count  coding_skill_score  \
# count   100000.000000         100000.000000       100000.000000
# mean         3.001860              2.005150           69.825326
# std          1.731764              1.416553           14.694618
# min          0.000000              0.000000           20.000000
# 25%          2.000000              1.000000           59.807945
# 50%          3.000000              2.000000           70.006250
# 75%          4.000000              3.000000           80.058762
# max         13.000000             11.000000          100.000000
#
#        aptitude_score  communication_skill_score  logical_reasoning_score  \
# count   100000.000000              100000.000000            100000.000000
# mean        64.988108                  67.960744                65.931696
# std         14.844093                  13.846636                14.826790
# min         20.000000                  20.000000                20.000000
# 25%         54.894600                  58.587535                55.940547
# 50%         65.011394                  67.973221                66.003829
# 75%         75.079266                  77.503749                76.113705
# max        100.000000                 100.000000               100.000000
#
#        ...   github_repos  linkedin_connections  mock_interview_score  \
# count  ...  100000.000000         100000.000000         100000.000000
# mean   ...       4.005160            524.559110             69.989411
# std    ...       2.004897            274.993479             11.937257
# min    ...       0.000000             50.000000             20.000000
# 25%    ...       3.000000            287.000000             61.973172
# 50%    ...       4.000000            523.000000             70.026665
# 75%    ...       5.000000            764.000000             78.122083
# max    ...      16.000000            999.000000            100.000000
#
#        attendance_percentage       backlogs  extracurricular_score  \
# count          100000.000000  100000.000000          100000.000000
# mean               84.730169       0.497590              59.894049
# std                 9.416075       0.708434              19.549666
# min                50.000000       0.000000               0.000000
# 25%                78.325833       0.000000              46.538590
# 50%                85.018828       0.000000              60.079021
# 75%                91.782511       1.000000              73.549567
# max               100.000000       6.000000             100.000000
#
#        leadership_score    sleep_hours  study_hours_per_day  \
# count     100000.000000  100000.000000        100000.000000
# mean          54.937526       6.983319             3.523124
# std           19.781197       1.468113             1.471248
# min            0.000000       3.000000             0.500000
# 25%           41.432390       6.000000             2.500000
# 50%           55.076210       7.000000             3.500000
# 75%           68.530115       8.000000             4.500000
# max          100.000000      10.000000            10.000000
#
#        salary_package_lpa
# count       100000.000000
# mean             7.252106
# std              6.735132
# min              0.000000
# 25%              0.000000
# 50%             11.100000
# 75%             13.470000
# max             20.440000
#
# [8 rows x 21 columns]

# %%
#Missing values in the dataset
df.isnull().sum()
# Out:
# student_id                   0
# age                          0
# gender                       0
# cgpa                         0
# branch                       0
# college_tier                 0
# internships_count            0
# projects_count               0
# certifications_count         0
# coding_skill_score           0
# aptitude_score               0
# communication_skill_score    0
# logical_reasoning_score      0
# hackathons_participated      0
# github_repos                 0
# linkedin_connections         0
# mock_interview_score         0
# attendance_percentage        0
# backlogs                     0
# extracurricular_score        0
# leadership_score             0
# volunteer_experience         0
# sleep_hours                  0
# study_hours_per_day          0
# placement_status             0
# salary_package_lpa           0
# dtype: int64

# %%
df.duplicated().sum()

#for remove duplicates
#df = df.drop_duplicates()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df["placement_status"].value_counts()
# Out:
# placement_status
# Placed        54459
# Not Placed    45541
# Name: count, dtype: int64

# %%
sns.countplot(x="placement_status", data=df)
plt.show()

# %%
#Correlation (Numeric Features)

plt.figure(figsize=(18,10))

sns.heatmap(
    df.select_dtypes(include=np.number).corr(),
    annot=True,
    cmap="coolwarm"
)

plt.show()

# %%
df.select_dtypes(include="object").columns
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_3272\1196084386.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include="object").columns
# Index(['gender', 'branch', 'college_tier', 'volunteer_experience',
#        'placement_status'],
#       dtype='str')

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

categorical_columns = [
    "gender",
    "branch",
    "college_tier",
    "volunteer_experience",
    "placement_status"
]

for col in categorical_columns:
    df[col] = encoder.fit_transform(df[col])

# %%
#Check Encoded Data
df.head()
# Out:
#    student_id  age  gender  cgpa  branch  college_tier  internships_count  \
# 0           1   24       1  7.53       4             1                  4
# 1           2   21       1  7.92       0             1                  1
# 2           3   22       0  8.60       3             0                  0
# 3           4   24       1  6.68       0             0                  0
# 4           5   20       0  8.43       4             2                  1
#
#    projects_count  certifications_count  coding_skill_score  ...  \
# 0               6                     1           99.238568  ...
# 1               3                     6           80.966123  ...
# 2               1                     1           49.177184  ...
# 3               2                     2           79.359084  ...
# 4               4                     3           65.018573  ...
#
#    mock_interview_score  attendance_percentage  backlogs  \
# 0             72.647009              77.463863         2
# 1             61.699110              88.887600         1
# 2             87.396911              74.153265         0
# 3             58.401069              87.635955         1
# 4             74.489201              79.120749         1
#
#    extracurricular_score  leadership_score  volunteer_experience  sleep_hours  \
# 0              63.382726         52.938240                     1          6.7
# 1              73.694605         60.198856                     0          4.4
# 2              63.329294         43.708803                     0          8.8
# 3              47.636099         56.549154                     1          8.1
# 4               0.000000         67.268893                     0          8.7
#
#    study_hours_per_day  placement_status  salary_package_lpa
# 0                  3.6                 0                0.00
# 1                  2.3                 0                0.00
# 2                  5.9                 1               11.99
# 3                  4.4                 0                0.00
# 4                  3.4                 1               12.16
#
# [5 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# age                          0
# gender                       0
# cgpa                         0
# branch                       0
# college_tier                 0
# internships_count            0
# projects_count               0
# certifications_count         0
# coding_skill_score           0
# aptitude_score               0
# communication_skill_score    0
# logical_reasoning_score      0
# hackathons_participated      0
# github_repos                 0
# linkedin_connections         0
# mock_interview_score         0
# attendance_percentage        0
# backlogs                     0
# extracurricular_score        0
# leadership_score             0
# volunteer_experience         0
# sleep_hours                  0
# study_hours_per_day          0
# placement_status             0
# salary_package_lpa           0
# dtype: int64

# %% [markdown]
# Feature Selection

# %%
df.drop("student_id", axis=1, inplace=True)

# %%
X = df.drop("placement_status", axis=1)

y = df["placement_status"]

# %%
print(X.shape)
print(y.shape)
# Out:
# (100000, 24)
# (100000,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

#80 -- 20 split for training and testing data

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print(X_train.shape)
print(X_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# (80000, 24)
# (20000, 24)
# (80000,)
# (20000,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(random_state=42)

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy :", accuracy)
# Out:
# Accuracy : 1.0

# %%
print(f"Accuracy: {accuracy:.2%}")
# Out:
# Accuracy: 100.00%

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[ 9127     0]
#  [    0 10873]]

# %%
plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues'
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Logistic Regression")

plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9127
#            1       1.00      1.00      1.00     10873
#
#     accuracy                           1.00     20000
#    macro avg       1.00      1.00      1.00     20000
# weighted avg       1.00      1.00      1.00     20000

# %%
train_accuracy = lr.score(X_train, y_train)

print("Training Accuracy :", train_accuracy)
# Out:
# Training Accuracy : 1.0

# %%
test_accuracy = lr.score(X_test, y_test)

print("Testing Accuracy :", test_accuracy)
# Out:
# Testing Accuracy : 1.0

# %%
print(f"Training Accuracy : {train_accuracy:.4f}")
print(f"Testing Accuracy  : {test_accuracy:.4f}")
# Out:
# Training Accuracy : 1.0000
# Testing Accuracy  : 1.0000

# %%
import joblib

joblib.dump(lr, "placement_model.pkl")
# Out:
# ['placement_model.pkl']

# %%
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
model = joblib.load("placement_model.pkl")

# %%
prediction = model.predict(X_test[:5])

print(prediction)
# Out:
# [0 1 1 1 1]

# %%
from sklearn.metrics import roc_curve, auc

y_prob = lr.predict_proba(X_test)[:,1]

fpr, tpr, _ = roc_curve(y_test, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.3f}")
plt.plot([0,1],[0,1],'--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
loaded_model = joblib.load("placement_model.pkl")

loaded_model.predict(X_test[:5])
# Out:
# array([0, 1, 1, 1, 1])
